# %% [markdown]
# # Variational Autoencoder Sequence-to-Sequence Model for Speech

# %% [markdown]
# Herman Kamper, Stellenbosch University, 2018.

# %% [markdown]
# ## Preamble

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from __future__ import division
from __future__ import print_function
from os import path
from scipy.spatial.distance import pdist
import matplotlib.pyplot as plt
import numpy as np
import sys
import tensorflow as tf

# %%
sys.path.append(path.join("..", "src"))

import plotting
import samediff
import tflego
import training

from tflego import NP_DTYPE, TF_DTYPE, NP_ITYPE, TF_ITYPE

output_dir = "/tmp/data-kamperh/"

# %% [markdown]
# ## Utility functions and classes

# %%
class ValIterator(object):
    
    def __init__(self, x_list, batch_size, shuffle_every_epoch=False):
        self.x_list = x_list
        self.batch_size = batch_size
        self.shuffle_every_epoch = shuffle_every_epoch
        self.n_input = self.x_list[0].shape[-1]
        self.x_lengths = np.array([i.shape[0] for i in x_list])
        self.n_batches = int(len(self.x_lengths)/batch_size)
        self.indices = np.arange(len(self.x_lengths))
        np.random.shuffle(self.indices)
    
    def __iter__(self):

        if self.shuffle_every_epoch:
            np.random.shuffle(self.indices)
        
        for i_batch in xrange(self.n_batches):

            batch_indices = self.indices[
                i_batch*self.batch_size:(i_batch + 1)*self.batch_size
                ]
            
            batch_x_lengths = self.x_lengths[batch_indices]

            # Pad to maximum length in batch
            batch_x_padded = np.zeros(
                (len(batch_indices), np.max(batch_x_lengths), self.n_input),
                 dtype=NP_DTYPE
                )
            for i, length in enumerate(batch_x_lengths):
                seq = self.x_list[batch_indices[i]]
                batch_x_padded[i, :length, :] = seq

            yield (batch_x_padded, batch_x_lengths)

# %%
class TrainIterator(object):
    
    def __init__(self, x_full_list, batch_size, n_buckets, min_dur=50, max_dur=100, shuffle_every_epoch=False):
        self.x_full_list = x_full_list
        self.batch_size = batch_size
        self.n_buckets = n_buckets
        self.min_dur = min_dur
        self.max_dur = max_dur
        self.shuffle_every_epoch = shuffle_every_epoch
        self.n_input = self.x_full_list[0].shape[-1]
        self.n_batches = int(len(self.x_full_list)/batch_size)
        
        self.sample_segments()

    def sample_segments(self):
        self.x_list = []
        for cur_x in self.x_full_list:
            cur_len = cur_x.shape[0]
            dur = np.random.randint(self.min_dur, min(self.max_dur, cur_len))
            start = np.random.randint(0, cur_len - dur)
            self.x_list.append(cur_x[start:start + dur, :])
        self.x_lengths = np.array([i.shape[0] for i in self.x_list])
        sorted_indices = np.argsort([len(i) for i in self.x_list])
        bucket_size = int(len(self.x_lengths)/self.n_buckets)
        self.buckets = []
        for i_bucket in xrange(self.n_buckets):
            self.buckets.append(
                sorted_indices[i_bucket*bucket_size:(i_bucket + 1)*bucket_size]
                )
        self.shuffle()

    def shuffle(self):
        for i_bucket in xrange(self.n_buckets):
            np.random.shuffle(self.buckets[i_bucket])
        self.indices = np.concatenate(self.buckets)
#         blocks = [self.indices[i:i + self.batch_size] for i in range(0, len(self.indices), self.batch_size)]
#         np.random.shuffle(blocks)
#         self.indices[:] = [b for bs in blocks for b in bs]
        
    def __iter__(self):

        if self.shuffle_every_epoch:
            self.sample_segments()
        
        for i_batch in xrange(self.n_batches):

            batch_indices = self.indices[
                i_batch*self.batch_size:(i_batch + 1)*self.batch_size
                ]
            
            batch_x_lengths = self.x_lengths[batch_indices]

            # Pad to maximum length in batch
            batch_x_padded = np.zeros(
                (len(batch_indices), np.max(batch_x_lengths), self.n_input),
                 dtype=NP_DTYPE
                )
            for i, length in enumerate(batch_x_lengths):
                seq = self.x_list[batch_indices[i]]
                batch_x_padded[i, :length, :] = seq

            yield (batch_x_padded, batch_x_lengths)

# %%
# Training data

# NumPy archive
npz = np.load(
    path.join("..", "features", "subsets", "devpart1",
    "devpart1.mfcc.cmvn_dd.npz")
    )

# Data and labels
train_x = []
train_labels = []
train_lengths = []
train_keys = []
n_items = 0
for utt_key in sorted(npz):
    if len(npz[utt_key]) <= 50:
        continue
    train_keys.append(utt_key)
    train_x.append(npz[utt_key])
    word = "_".join(utt_key.split("_")[:-2])
    train_labels.append(word)
    train_lengths.append(npz[utt_key].shape[0])
    n_items += 1
print("No. items:", n_items)
print("E.g. item shape:", train_x[0].shape)
# Out:
# No. items: 14753
# E.g. item shape: (80, 39)

# %%
plt.imshow(train_x[3277].T, origin="bottom");

# %%
# Development data

# NumPy archive
npz = np.load(
    path.join("..", "features", "wordpairs", "devpart2",
    "devpart2.samediff.mfcc.cmvn_dd.npz")
    )

# Data and labels
val_x = []
val_labels = []
val_lengths = []
val_keys = []
n_items = 0
for utt_key in sorted(npz):
    val_keys.append(utt_key)
    val_x.append(npz[utt_key])
    word = "_".join(utt_key.split("_")[:-2])
    val_labels.append(word)
    val_lengths.append(npz[utt_key].shape[0])
    n_items += 1
print("No. items:", n_items)
print("E.g. item shape:", val_x[0].shape)
# Out:
# No. items: 2733
# E.g. item shape: (61, 39)

# %%
# Truncate and limit dimensionality
max_length = 100
d_frame = 13  # None
for i, seq in enumerate(train_x):
    train_x[i] = train_x[i][:max_length, :d_frame]
    train_lengths[i] = min(train_lengths[i], max_length)
for i, seq in enumerate(val_x):
    val_x[i] = val_x[i][:max_length, :d_frame]
    val_lengths[i] = min(val_lengths[i], max_length)

# %%
plt.imshow(train_x[3277].T, origin="bottom");

# %% [markdown]
# ## Multi-layer sequence-to-sequence model with latent VAE representation

# %%
tf.reset_default_graph()

# Training parameters
learning_rate = 0.001
n_epochs = 100  # 100
n_val_interval = 1
batch_size = 200  # 100
n_buckets = 3

# Model parameters
n_input = d_frame
enc_n_hiddens = [400, 400, 400] # 150
dec_n_hiddens = [400, 400, 400]
build_latent_func = tflego.build_vae
latent_func_kwargs = {
    "enc_n_hiddens": [],
    "n_z": 130, # 130,
    "dec_n_hiddens": [dec_n_hiddens[0]],
    "activation": tf.nn.relu
    }
rnn_type = "gru" # "lstm", "gru" or "rnn"
intermediate_model_fn = path.join(output_dir, "multi_lazydynamic_latent_vae.tmp.ckpt")
model_fn = path.join(output_dir, "multi_lazydynamic_latent_vae.ckpt")

# Model
x = tf.placeholder(TF_DTYPE, [None, None, n_input])
x_lengths = tf.placeholder(TF_ITYPE, [None])
network_dict = tflego.build_multi_encdec_lazydynamic_latentfunc(
    x, x_lengths, enc_n_hiddens, dec_n_hiddens, build_latent_func,
    latent_func_kwargs, rnn_type=rnn_type
    )
encoder_states = network_dict["encoder_states"]
vae = network_dict["latent_layer"]
z_mean = vae["z_mean"]
z_log_sigma_sq = vae["z_log_sigma_sq"]
z = vae["z"]
y = network_dict["decoder_output"]
mask = network_dict["mask"]

y *= tf.expand_dims(mask, -1)  # safety

# VAE loss
sigma_sq = 0.00001  # smaller values: care more about reconstruction
reconstruction_loss = tf.reduce_mean(
    tf.reduce_sum(tf.reduce_mean(tf.square(x - y), -1), -1) /
    tf.reduce_sum(mask, 1)
    )  # https://danijar.com/variable-sequence-lengths-in-tensorflow/
loss = tflego.vae_loss_gaussian(x, y, sigma_sq, z_mean, z_log_sigma_sq, reconstruction_loss=reconstruction_loss)

optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

# %%
def samediff_val():
    # Embed validation
    np.random.seed(1)
    val_batch_iterator = ValIterator(
        val_x, len(val_x), False
        )
    labels = [val_labels[i] for i in val_batch_iterator.indices]
    saver = tf.train.Saver()
    with tf.Session() as session:
        saver.restore(session, intermediate_model_fn)
        for batch_x_padded, batch_x_lengths in val_batch_iterator:
            np_x = batch_x_padded
            np_x_lengths = batch_x_lengths
            np_z = session.run(
                [z_mean], feed_dict={x: np_x, x_lengths: np_x_lengths}
                )[0]
#             np_y = session.run(
#                 [y], feed_dict={x: np_x, x_lengths: np_x_lengths}
#                 )[0]
            break  # single batch

    embed_dict = {}
    for i, utt_key in enumerate([val_keys[i] for i in val_batch_iterator.indices]):
        embed_dict[utt_key] = np_z[i]
    
    # Same-different
    distances = pdist(np_z, metric="cosine")
    matches = samediff.generate_matches_array(labels)
    ap, prb = samediff.average_precision(
        distances[matches == True], distances[matches == False]
        )
    
    return [prb, -ap]

# %%
np.random.seed(1)
train_batch_iterator = TrainIterator(
    train_x, batch_size, n_buckets, shuffle_every_epoch=True
    )
# val_batch_iterator = ValIterator(
#     val_x, batch_size, False
#     )

# record_dict = training.train_fixed_epochs(
#     n_epochs, optimizer, loss, train_batch_iterator,
#     [x, x_lengths], [loss, reconstruction_loss], val_batch_iterator, save_best_val_model_fn=model_fn
#     )
record_dict = training.train_fixed_epochs_external_val(
    n_epochs, optimizer, loss, train_batch_iterator,
    [x, x_lengths], samediff_val, save_model_fn=intermediate_model_fn, save_best_val_model_fn=model_fn,
    n_val_interval=n_val_interval
    )
# Out:
# 2018-08-17 18:01:01.317883
# Epoch 0:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 21.729 sec, train loss: 43353.3, val loss: [0.06317103674373542, -0.02199019134376869] *
# Epoch 1:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 21.838 sec, train loss: 35934.1, val loss: [0.12728678175727906, -0.06702893018636126] *
# Epoch 2:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 21.624 sec, train loss: 32684.0, val loss: [0.17263591857768618, -0.1073379003324188] *
# Epoch 3:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 21.676 sec, train loss: 30521.1, val loss: [0.19711414583870138, -0.13623533877584668] *
# Epoch 4:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 21.693 sec, train loss: 28809.4, val loss: [0.20484411234217986, -0.14435080633903863] *
# Epoch 5:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 21.676 sec, train loss: 27133.3, val loss: [0.22081937644936872, -0.16162964593515819] *
# Epoch 6:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.034 sec, train loss: 26107.8, val loss: [0.23292965730481835, -0.17613362181818693] *
# Epoch 7:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 21.824 sec, train loss: 24560.1, val loss: [0.24194795155887658, -0.1843172658487908] *
# Epoch 8:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.102 sec, train loss: 23178.7, val loss: [0.25917815707668945, -0.20361375349739161] *
# Epoch 9:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 21.870 sec, train loss: 22447.2, val loss: [0.26073545298787237, -0.20444124036835842] *
# Epoch 10:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.198 sec, train loss: 21290.0, val loss: [0.26513785106931204, -0.21171988860816299] *
# Epoch 11:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 21.922 sec, train loss: 21558.6, val loss: [0.26127286781757281, -0.20918609576565617]
# Epoch 12:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.381 sec, train loss: 19889.0, val loss: [0.25199690801339863, -0.19772527067060044]
# Epoch 13:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.146 sec, train loss: 19250.9, val loss: [0.25766555011594949, -0.20492688414473936]
# Epoch 14:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.178 sec, train loss: 19170.3, val loss: [0.26281886111826847, -0.21004123574186548]
# Epoch 15:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.479 sec, train loss: 18094.7, val loss: [0.25715021901571761, -0.20209161842137327]
# Epoch 16:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.236 sec, train loss: 18144.1, val loss: [0.25531367163320007, -0.20632484436048276]
# Epoch 17:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.303 sec, train loss: 18271.8, val loss: [0.25257597533842741, -0.20025423684820343]
# Epoch 18:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.677 sec, train loss: 17791.0, val loss: [0.24938812728651627, -0.1948081392001719]
# Epoch 19:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.378 sec, train loss: 17129.5, val loss: [0.25637722236536975, -0.202669180730041]
# Epoch 20:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.443 sec, train loss: 17562.4, val loss: [0.26030395112171445, -0.20954544594495789]
# Epoch 21:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.809 sec, train loss: 18892.6, val loss: [0.27647513527441381, -0.22326103207219039] *
# Epoch 22:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.346 sec, train loss: 17547.2, val loss: [0.26127286781757281, -0.20835529699442204]
# Epoch 23:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.867 sec, train loss: 15154.5, val loss: [0.25818088121618138, -0.20475454708588589]
# Epoch 24:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.566 sec, train loss: 14953.5, val loss: [0.26567932022998308, -0.21288520526784976]
# Epoch 25:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.598 sec, train loss: 16063.7, val loss: [0.26950811745967629, -0.21977755359527404]
# Epoch 26:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.014 sec, train loss: 17439.2, val loss: [0.27261015202267458, -0.22417605421858161] *
# Epoch 27:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.541 sec, train loss: 17665.9, val loss: [0.27699046637464569, -0.22605196722901474] *
# Epoch 28:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.596 sec, train loss: 17469.2, val loss: [0.27956712187580518, -0.23153307312514942] *
# Epoch 29:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.627 sec, train loss: 17556.7, val loss: [0.27802112857510952, -0.22808131918657043]
# Epoch 30:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.804 sec, train loss: 18115.1, val loss: [0.28034011852615304, -0.23262373666789962] *
# Epoch 31:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.731 sec, train loss: 16675.4, val loss: [0.27647513527441381, -0.22797054148985882]
# Epoch 32:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.907 sec, train loss: 15568.3, val loss: [0.27157948982221075, -0.22263408841858137]
# Epoch 33:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.367 sec, train loss: 14696.3, val loss: [0.26771450657047152, -0.21973997147447832]
# Epoch 34:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 22.975 sec, train loss: 15065.4, val loss: [0.27441381087348621, -0.22653330459904725]
# Epoch 35:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.402 sec, train loss: 17668.3, val loss: [0.27621746972429784, -0.22547876977933798]
# Epoch 36:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.045 sec, train loss: 17352.9, val loss: [0.27154451049585548, -0.22079791161569487]
# Epoch 37:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.129 sec, train loss: 16281.0, val loss: [0.27467147642360218, -0.22324877215526601]
# Epoch 38:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.517 sec, train loss: 16919.9, val loss: [0.27905179077557329, -0.23297140027679622] *
# Epoch 39:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.350 sec, train loss: 17162.1, val loss: [0.27546682973985864, -0.22939682939703457]
# Epoch 40:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.299 sec, train loss: 16780.3, val loss: [0.27879412522545738, -0.23078320139400404]
# Epoch 41:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.251 sec, train loss: 16440.2, val loss: [0.27364081422313835, -0.22516001422210213]
# Epoch 42:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.740 sec, train loss: 16444.8, val loss: [0.28034011852615304, -0.23260209977988378]
# Epoch 43:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.356 sec, train loss: 16798.0, val loss: [0.27621746972429784, -0.23037146675711501]
# Epoch 44:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.838 sec, train loss: 16735.9, val loss: [0.27524470430273595, -0.22719980958790972]
# Epoch 45:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.426 sec, train loss: 16081.0, val loss: [0.27679029945939337, -0.22848681404452154]
# Epoch 46:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.920 sec, train loss: 15996.7, val loss: [0.28034011852615304, -0.23152957513394931]
# Epoch 47:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.499 sec, train loss: 16898.2, val loss: [0.27492914197371809, -0.22754393025300126]
# Epoch 48:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.533 sec, train loss: 16272.8, val loss: [0.27392143350145726, -0.22644228135222774]
# Epoch 49:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.073 sec, train loss: 15612.7, val loss: [0.27595980417418192, -0.2271312855675206]
# Epoch 50:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.630 sec, train loss: 15982.5, val loss: [0.27827879412522544, -0.22855602481447937]
# Epoch 51:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.155 sec, train loss: 16120.8, val loss: [0.27241111318219741, -0.22805779742345825]
# Epoch 52:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.653 sec, train loss: 15434.1, val loss: [0.27029116207163101, -0.22181052426778283]
# Epoch 53:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.235 sec, train loss: 14781.9, val loss: [0.27257503994745269, -0.22729343842810001]
# Epoch 54:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.793 sec, train loss: 15121.3, val loss: [0.27157948982221075, -0.22535734263338736]
# Epoch 55:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.365 sec, train loss: 15757.3, val loss: [0.27724813192476166, -0.23422756176223816] *
# Epoch 56:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.466 sec, train loss: 17110.2, val loss: [0.28291677402731252, -0.23706136331382466] *
# Epoch 57:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.558 sec, train loss: 17157.7, val loss: [0.28446276732800824, -0.24130569890255915] *
# Epoch 58:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.655 sec, train loss: 17128.8, val loss: [0.27695479011674068, -0.22926355049545158]
# Epoch 59:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.520 sec, train loss: 17367.1, val loss: [0.27029116207163101, -0.22279725517912721]
# Epoch 60:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 23.984 sec, train loss: 16156.9, val loss: [0.27237603726305581, -0.22453639471476519]
# Epoch 61:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.642 sec, train loss: 16759.5, val loss: [0.27183715537232672, -0.22238206973200422]
# Epoch 62:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.117 sec, train loss: 16174.2, val loss: [0.27183715537232672, -0.22726741147069796]
# Epoch 63:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.274 sec, train loss: 15852.3, val loss: [0.27879412522545738, -0.23517845906810947]
# Epoch 64:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.682 sec, train loss: 16953.8, val loss: [0.27647513527441381, -0.23172376917905604]
# Epoch 65:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.322 sec, train loss: 17199.7, val loss: [0.27595980417418192, -0.22710288882416807]
# Epoch 66:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.803 sec, train loss: 17566.5, val loss: [0.27492914197371809, -0.22593641618918842]
# Epoch 67:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.400 sec, train loss: 16951.5, val loss: [0.27721242247963995, -0.22745915869198419]
# Epoch 68:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.899 sec, train loss: 16242.2, val loss: [0.26874516877093535, -0.22207709155972361]
# Epoch 69:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.462 sec, train loss: 15677.5, val loss: [0.26410718886884821, -0.2165924483275774]
# Epoch 70:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.967 sec, train loss: 15379.2, val loss: [0.27183715537232672, -0.22273613009883278]
# Epoch 71:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.518 sec, train loss: 15154.9, val loss: [0.27804937179205236, -0.22983785620088018]
# Epoch 72:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.087 sec, train loss: 14634.6, val loss: [0.27054882762174698, -0.22524595757031379]
# Epoch 73:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.599 sec, train loss: 14332.7, val loss: [0.27463609885064705, -0.22736666144913753]
# Epoch 74:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.193 sec, train loss: 14766.6, val loss: [0.27853645967534141, -0.23126196688464634]
# Epoch 75:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.720 sec, train loss: 15357.7, val loss: [0.27828548759759214, -0.22973590366506433]
# Epoch 76:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.308 sec, train loss: 14937.4, val loss: [0.27518680752383406, -0.22735235489827788]
# Epoch 77:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.770 sec, train loss: 14820.0, val loss: [0.27905179077557329, -0.23013338488490359]
# Epoch 78:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.393 sec, train loss: 14591.3, val loss: [0.27392143350145726, -0.22673814849462359]
# Epoch 79:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.852 sec, train loss: 15125.7, val loss: [0.27421430753163106, -0.22716058714483178]
# Epoch 80:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.459 sec, train loss: 15025.5, val loss: [0.27982478742592115, -0.22910356190628733]
# Epoch 81:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.890 sec, train loss: 14866.2, val loss: [0.27853645967534141, -0.23006934581975971]
# Epoch 82:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.584 sec, train loss: 14888.9, val loss: [0.27933604401995077, -0.2292891645700485]
# Epoch 83:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 24.978 sec, train loss: 14790.3, val loss: [0.2846837610037195, -0.23624303532425392]
# Epoch 84:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.624 sec, train loss: 14544.5, val loss: [0.27956712187580518, -0.22887202212736654]
# Epoch 85:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.044 sec, train loss: 14341.6, val loss: [0.27389847977325432, -0.22391782598000096]
# Epoch 86:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.772 sec, train loss: 14543.8, val loss: [0.27930945632568926, -0.22833790249829947]
# Epoch 87:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.151 sec, train loss: 14841.4, val loss: [0.28240144292708064, -0.2345047352168258]
# Epoch 88:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.861 sec, train loss: 14464.2, val loss: [0.28368977067766038, -0.2348309749967494]
# Epoch 89:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.229 sec, train loss: 14024.7, val loss: [0.28214377737696472, -0.23435761699192184]
# Epoch 90:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.948 sec, train loss: 14657.7, val loss: [0.28729708837928369, -0.23915271071299191]
# Epoch 91:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.327 sec, train loss: 14950.2, val loss: [0.28111311517650089, -0.23363621045992139]
# Epoch 92:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 26.002 sec, train loss: 14313.2, val loss: [0.28008245297603712, -0.23080691979309664]
# Epoch 93:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.397 sec, train loss: 14221.0, val loss: [0.27930945632568926, -0.22937648632450744]
# Epoch 94:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 26.123 sec, train loss: 14097.3, val loss: [0.28111311517650089, -0.2310293765755162]
# Epoch 95:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.491 sec, train loss: 13880.3, val loss: [0.28422407509079994, -0.23790272821622246]
# Epoch 96:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 26.212 sec, train loss: 13419.0, val loss: [0.28111311517650089, -0.22964839435843187]
# Epoch 97:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.539 sec, train loss: 12958.2, val loss: [0.27879412522545738, -0.23222607592657932]
# Epoch 98:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 26.280 sec, train loss: 13155.9, val loss: [0.27389847977325432, -0.22585034518811012]
# Epoch 99:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# 25.627 sec, train loss: 13480.6, val loss: [0.28190598073319784, -0.23634785858758683]
# Writing: /tmp/data-kamperh/multi_lazydynamic_latent_vae.tmp.ckpt
# Training time: 39.651 min
# 2018-08-17 18:41:03.320257

# %%
# Embed validation
val_batch_iterator = ValIterator(
    val_x, len(val_x), False
    )
labels = [val_labels[i] for i in val_batch_iterator.indices]
saver = tf.train.Saver()
with tf.Session() as session:
    saver.restore(session, model_fn)
    for batch_x_padded, batch_x_lengths in val_batch_iterator:
        np_x = batch_x_padded
        np_x_lengths = batch_x_lengths
        np_z = session.run(
            [z_mean], feed_dict={x: np_x, x_lengths: np_x_lengths}
            )[0]
        np_y = session.run(
            [y], feed_dict={x: np_x, x_lengths: np_x_lengths}
            )[0]
        break  # single batch

embed_dict = {}
for i, utt_key in enumerate([val_keys[i] for i in val_batch_iterator.indices]):
    embed_dict[utt_key] = np_z[i]
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/multi_lazydynamic_latent_vae.ckpt

# %%
# Same-different evaluation
distances = pdist(np_z, metric="cosine")
matches = samediff.generate_matches_array(labels)
ap, prb = samediff.average_precision(
    distances[matches == True], distances[matches == False]
    )

print("Average precision: {:.4f}".format(ap))
print("Precision-recall breakeven: {:.4f}".format(prb))
# Out:
# Average precision: 0.2413
# Precision-recall breakeven: 0.2845

# %%
# Same-different evaluation after normalisation
np_z_normalised = (np_z - np_z.mean(axis=0))/np_z.std(axis=0)
distances = pdist(np_z_normalised, metric="cosine")
matches = samediff.generate_matches_array(labels)
ap, prb = samediff.average_precision(
    distances[matches == True], distances[matches == False]
    )

print("Average precision: {:.4f}".format(ap))
print("Precision-recall breakeven: {:.4f}".format(prb))
# Out:
# Average precision: 0.2486
# Precision-recall breakeven: 0.2914

# %%
# Plot reconstruction
plt.figure(figsize=(12, 8))
for i in range(5):
    plt.subplot(5, 2, 2*i + 1)
    if i == 0:
        plt.title("Input")
    plt.imshow(np_x[i][:np_x_lengths[i]].T)
    plt.axis("off")
    plt.subplot(5, 2, 2*i + 2)
    if i == 0:
        plt.title("Reconstruction")
    plt.imshow(np_y[i][:np_x_lengths[i]].T)
    plt.axis("off")

# %%
plotting.plot_raw_embeds(
    embed_dict, ["because", "yknow", "people", "something", "anything", "education", "situation"],
    mvn=False, figsize=(12, 8)
    )
