# %% [markdown]
# # Autoencoder Sequence-to-Sequence Model for Speech

# %% [markdown]
# Herman Kamper, Stellenbosch University, 2018.

# %% [markdown]
# ## Preamble

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

from __future__ import division
from __future__ import print_function
from os import path
from scipy.spatial.distance import pdist
import matplotlib.pyplot as plt
import numpy as np
import sys
import tensorflow as tf

# %%
sys.path.append(path.join("..", "src"))

import plotting
import samediff
import tflego
import training

from tflego import NP_DTYPE, TF_DTYPE, NP_ITYPE, TF_ITYPE

output_dir = "/tmp/data-kamperh/"

# %% [markdown]
# ## Utility functions and classes

# %%
class SimpleIterator(object):
    
    def __init__(self, x_list, batch_size, shuffle_every_epoch=False):
        self.x_list = x_list
        self.batch_size = batch_size
        self.shuffle_every_epoch = shuffle_every_epoch
        self.n_input = self.x_list[0].shape[-1]
        self.x_lengths = np.array([i.shape[0] for i in x_list])
        self.n_batches = int(len(self.x_lengths)/batch_size)
        self.indices = np.arange(len(self.x_lengths))
        np.random.shuffle(self.indices)
    
    def __iter__(self):

        if self.shuffle_every_epoch:
            np.random.shuffle(self.indices)
        
        for i_batch in xrange(self.n_batches):

            batch_indices = self.indices[
                i_batch*self.batch_size:(i_batch + 1)*self.batch_size
                ]
            
            batch_x_lengths = self.x_lengths[batch_indices]

            # Pad to maximum length in batch
            batch_x_padded = np.zeros(
                (len(batch_indices), np.max(batch_x_lengths), self.n_input),
                 dtype=NP_DTYPE
                )
            for i, length in enumerate(batch_x_lengths):
                seq = self.x_list[batch_indices[i]]
                batch_x_padded[i, :length, :] = seq

            yield (batch_x_padded, batch_x_lengths)

# %%
class SimpleBucketIterator(object):
    
    def __init__(self, x_list, batch_size, n_buckets, shuffle_every_epoch=False):
        self.x_list = x_list
        self.batch_size = batch_size
        self.shuffle_every_epoch = shuffle_every_epoch
        self.n_input = self.x_list[0].shape[-1]
        self.x_lengths = np.array([i.shape[0] for i in x_list])
        self.n_batches = int(len(self.x_lengths)/batch_size)
        
        # Set up bucketing
        self.n_buckets = n_buckets
        sorted_indices = np.argsort([len(i) for i in x_list])
        bucket_size = int(len(self.x_lengths)/self.n_buckets)
        self.buckets = []
        for i_bucket in xrange(n_buckets):
            self.buckets.append(
                sorted_indices[i_bucket*bucket_size:(i_bucket + 1)*bucket_size]
                )
        self.shuffle()
            
    def shuffle(self):
        for i_bucket in xrange(self.n_buckets):
            np.random.shuffle(self.buckets[i_bucket])
        self.indices = np.concatenate(self.buckets)
    
    def __iter__(self):

        if self.shuffle_every_epoch:
            self.shuffle()
        
        for i_batch in xrange(self.n_batches):

            batch_indices = self.indices[
                i_batch*self.batch_size:(i_batch + 1)*self.batch_size
                ]
            
            batch_x_lengths = self.x_lengths[batch_indices]

            # Pad to maximum length in batch
            batch_x_padded = np.zeros(
                (len(batch_indices), np.max(batch_x_lengths), self.n_input),
                 dtype=NP_DTYPE
                )
            for i, length in enumerate(batch_x_lengths):
                seq = self.x_list[batch_indices[i]]
                batch_x_padded[i, :length, :] = seq

            yield (batch_x_padded, batch_x_lengths)

# %% [markdown]
# ## Data

# %%
# Training data

# NumPy archive
npz = np.load(
    path.join("..", "features", "wordpairs", "devpart1",
    "devpart1.samediff.mfcc.cmvn_dd.npz")
    )

# Data and labels
train_x = []
train_labels = []
train_lengths = []
train_keys = []
n_items = 0
for utt_key in sorted(npz):
    train_keys.append(utt_key)
    train_x.append(npz[utt_key])
    word = "_".join(utt_key.split("_")[:-2])
    train_labels.append(word)
    train_lengths.append(npz[utt_key].shape[0])
    n_items += 1
print("No. items:", n_items)
print("E.g. item shape:", train_x[0].shape)
# Out:
# No. items: 5106
# E.g. item shape: (51, 39)

# %%
plt.imshow(train_x[3277].T, origin="bottom");

# %%
# Development data

# NumPy archive
npz = np.load(
    path.join("..", "features", "wordpairs", "devpart2",
    "devpart2.samediff.mfcc.cmvn_dd.npz")
    )

# Data and labels
val_x = []
val_labels = []
val_lengths = []
val_keys = []
n_items = 0
for utt_key in sorted(npz):
    val_keys.append(utt_key)
    val_x.append(npz[utt_key])
    word = "_".join(utt_key.split("_")[:-2])
    val_labels.append(word)
    val_lengths.append(npz[utt_key].shape[0])
    n_items += 1
print("No. items:", n_items)
print("E.g. item shape:", val_x[0].shape)
# Out:
# No. items: 2733
# E.g. item shape: (61, 39)

# %%
# Truncate and limit dimensionality
max_length = 100
d_frame = 13  # None
for i, seq in enumerate(train_x):
    train_x[i] = train_x[i][:max_length, :d_frame]
    train_lengths[i] = min(train_lengths[i], max_length)
for i, seq in enumerate(val_x):
    val_x[i] = val_x[i][:max_length, :d_frame]
    val_lengths[i] = min(val_lengths[i], max_length)

# %%
plt.imshow(train_x[3277].T, origin="bottom");

# %%
# First scale mean and variance
train_frames = []
for seq in train_x:
    for frame in seq:
        train_frames.append(frame)
train_frames = np.array(train_frames)
mean = train_frames.mean(axis=0)
std = train_frames.mean(std=0)

# Scale training and validation to between 0 and 1
train_x_scaled = []
val_x_scaled = []
for seq in train_x:
    cur_seq = np.clip(
        (seq - train_x_min)/(train_x_max - train_x_min),
        train_x_min, train_x_max
        )
    train_x_scaled.append(cur_seq)
for seq in val_x:
    cur_seq = np.clip(
        (seq - train_x_min)/(train_x_max - train_x_min),
        train_x_min, train_x_max
        )
    val_x_scaled.append(cur_seq)
# Out:
# [-0.18835604  0.10080495  0.04498608  0.03460926  0.10017443 -0.00485604
#   0.0443855   0.0307119   0.04660019 -0.00969341  0.05738148  0.11984802
#  -0.10351756]

# %%
plt.imshow(train_x_scaled[3277].T, origin="bottom");
print(np.min(train_x_scaled[3277]), np.max(train_x_scaled[3277]))
# Out:
# 0.175464265195 0.786332038359

# %% [markdown]
# ## Autoencoder with direct decoding

# %% [markdown]
# Here the final state of the encoder is passed on directly to the decoder (without any intermediate transformation).

# %%
tf.reset_default_graph()

# Training parameters
learning_rate = 0.001
n_epochs = 50  # 50
batch_size = 100
n_buckets = 3

# Model parameters
n_input = d_frame
n_hidden = 150
rnn_type = "gru"  # "lstm", "gru" or "rnn"
model_fn = path.join(output_dir, "lazydynamic_ae.ckpt")

# Model
x = tf.placeholder(TF_DTYPE, [None, None, n_input])
x_lengths = tf.placeholder(TF_ITYPE, [None])
network_dict = tflego.build_encdec_lazydynamic(
    x, x_lengths, n_hidden, rnn_type=rnn_type
    )
encoder_states = network_dict["encoder_states"]
y = network_dict["decoder_output"]
mask = network_dict["mask"]

y *= tf.expand_dims(mask, -1)  # safety

# Reconstruction loss
loss = tf.reduce_mean(
    tf.reduce_sum(tf.reduce_mean(tf.square(x - y), -1), -1) /
    tf.reduce_sum(mask, 1)
    )  # https://danijar.com/variable-sequence-lengths-in-tensorflow/

optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

# %%
np.random.seed(1)
train_batch_iterator = SimpleBucketIterator(
    train_x, batch_size, n_buckets, True
    )
val_batch_iterator = SimpleBucketIterator(
    val_x, batch_size, n_buckets, False
    )

record_dict = training.train_fixed_epochs(
    n_epochs, optimizer, loss, train_batch_iterator,
    [x, x_lengths], loss, val_batch_iterator, save_best_val_model_fn=model_fn
    )
# Out:
# 2018-06-11 11:58:42.172534
# Epoch 0:
# 3.510 sec, train loss: 0.926742, val loss: 0.775968 *
# Epoch 1:
# 3.359 sec, train loss: 0.727186, val loss: 0.687394 *
# Epoch 2:
# 3.364 sec, train loss: 0.648977, val loss: 0.654442 *
# Epoch 3:
# 3.383 sec, train loss: 0.635469, val loss: 0.626996 *
# Epoch 4:
# 3.358 sec, train loss: 0.586699, val loss: 0.602716 *
# Epoch 5:
# 3.365 sec, train loss: 0.549258, val loss: 0.55305 *
# Epoch 6:
# 3.366 sec, train loss: 0.519703, val loss: 0.546202 *
# Epoch 7:
# 3.387 sec, train loss: 0.487933, val loss: 0.508338 *
# Epoch 8:
# 3.372 sec, train loss: 0.483006, val loss: 0.52048
# Epoch 9:
# 3.369 sec, train loss: 0.466497, val loss: 0.518474
# Epoch 10:
# 3.360 sec, train loss: 0.454116, val loss: 0.488978 *
# Epoch 11:
# 3.370 sec, train loss: 0.425874, val loss: 0.466728 *
# Epoch 12:
# 3.363 sec, train loss: 0.436099, val loss: 0.484989
# Epoch 13:
# 3.363 sec, train loss: 0.434821, val loss: 0.46735
# Epoch 14:
# 3.373 sec, train loss: 0.410614, val loss: 0.474381
# Epoch 15:
# 3.364 sec, train loss: 0.391997, val loss: 0.477202
# Epoch 16:
# 3.386 sec, train loss: 0.391796, val loss: 0.475109
# Epoch 17:
# 3.365 sec, train loss: 0.381925, val loss: 0.487349
# Epoch 18:
# 3.361 sec, train loss: 0.388495, val loss: 0.435914 *
# Epoch 19:
# 3.357 sec, train loss: 0.367417, val loss: 0.446279
# Epoch 20:
# 3.362 sec, train loss: 0.362042, val loss: 0.377721 *
# Epoch 21:
# 3.370 sec, train loss: 0.355108, val loss: 0.414108
# Epoch 22:
# 3.353 sec, train loss: 0.343613, val loss: 0.413131
# Epoch 23:
# 3.368 sec, train loss: 0.343918, val loss: 0.3918
# Epoch 24:
# 3.360 sec, train loss: 0.332728, val loss: 0.400753
# Epoch 25:
# 3.386 sec, train loss: 0.337552, val loss: 0.45934
# Epoch 26:
# 3.372 sec, train loss: 0.339776, val loss: 0.38465
# Epoch 27:
# 3.365 sec, train loss: 0.325384, val loss: 0.37711 *
# Epoch 28:
# 3.360 sec, train loss: 0.335475, val loss: 0.41875
# Epoch 29:
# 3.361 sec, train loss: 0.32627, val loss: 0.39464
# Epoch 30:
# 3.370 sec, train loss: 0.316951, val loss: 0.359802 *
# Epoch 31:
# 3.361 sec, train loss: 0.311487, val loss: 0.374283
# Epoch 32:
# 3.372 sec, train loss: 0.304217, val loss: 0.344834 *
# Epoch 33:
# 3.370 sec, train loss: 0.291903, val loss: 0.360815
# Epoch 34:
# 3.386 sec, train loss: 0.288255, val loss: 0.324771 *
# Epoch 35:
# 3.363 sec, train loss: 0.292688, val loss: 0.327624
# Epoch 36:
# 3.357 sec, train loss: 0.293071, val loss: 0.323736 *
# Epoch 37:
# 3.360 sec, train loss: 0.292316, val loss: 0.32038 *
# Epoch 38:
# 3.351 sec, train loss: 0.27612, val loss: 0.326115
# Epoch 39:
# 3.351 sec, train loss: 0.268719, val loss: 0.31715 *
# Epoch 40:
# 3.351 sec, train loss: 0.265991, val loss: 0.310245 *
# Epoch 41:
# 3.344 sec, train loss: 0.279298, val loss: 0.309375 *
# Epoch 42:
# 3.365 sec, train loss: 0.266848, val loss: 0.289478 *
# Epoch 43:
# 3.344 sec, train loss: 0.262885, val loss: 0.317455
# Epoch 44:
# 3.337 sec, train loss: 0.270257, val loss: 0.329613
# Epoch 45:
# 3.329 sec, train loss: 0.256531, val loss: 0.288601 *
# Epoch 46:
# 3.328 sec, train loss: 0.24221, val loss: 0.296766
# Epoch 47:
# 3.336 sec, train loss: 0.246882, val loss: 0.289287
# Epoch 48:
# 3.325 sec, train loss: 0.24248, val loss: 0.293617
# Epoch 49:
# 3.336 sec, train loss: 0.24671, val loss: 0.276453 *
# Training time: 2.803 min
# 2018-06-11 12:01:32.612665

# %%
# Embed validation
val_batch_iterator = SimpleIterator(
    val_x, len(val_x), False
    )
labels = [val_labels[i] for i in val_batch_iterator.indices]
saver = tf.train.Saver()
with tf.Session() as session:
    saver.restore(session, model_fn)
    for batch_x_padded, batch_x_lengths in val_batch_iterator:
        np_x = batch_x_padded
        np_x_lengths = batch_x_lengths
        np_z = session.run(
            [encoder_states], feed_dict={x: np_x, x_lengths: np_x_lengths}
            )[0]
        np_y = session.run(
            [y], feed_dict={x: np_x, x_lengths: np_x_lengths}
            )[0]
        break  # single batch

embed_dict = {}
for i, utt_key in enumerate([val_keys[i] for i in val_batch_iterator.indices]):
    embed_dict[utt_key] = np_z[i]
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/lazydynamic_ae.ckpt

# %%
# Same-different evaluation
distances = pdist(np_z, metric="cosine")
matches = samediff.generate_matches_array(labels)
ap, prb = samediff.average_precision(
    distances[matches == True], distances[matches == False]
    )

print("Average precision: {:.4f}".format(ap))
print("Precision-recall breakeven: {:.4f}".format(prb))
# Out:
# Average precision: 0.1802
# Precision-recall breakeven: 0.2276

# %%
# Plot reconstruction
plt.figure(figsize=(12, 8))
for i in range(5):
    plt.subplot(5, 2, 2*i + 1)
    if i == 0:
        plt.title("Input")
    plt.imshow(np_x[i][:np_x_lengths[i]].T)
    plt.axis("off")
    plt.subplot(5, 2, 2*i + 2)
    if i == 0:
        plt.title("Reconstruction")
    plt.imshow(np_y[i][:np_x_lengths[i]].T)
    plt.axis("off")

# %%
plotting.plot_raw_embeds(
    embed_dict, ["because", "yknow", "people", "something", "anything", "education", "situation"],
    figsize=(12, 8)
    )

# %% [markdown]
# ## Autoencoder with latent transformation

# %% [markdown]
# After the encoder, a transformation is performed to obtain the latent representation, before conditioning the decoder.

# %%
tf.reset_default_graph()

# Training parameters
learning_rate = 0.001
n_epochs = 200  # 50
batch_size = 100
n_buckets = 3

# Model parameters
n_input = d_frame
n_hidden = 150
build_latent_func = tflego.build_autoencoder
latent_func_kwargs = {
    "enc_n_hiddens": [],
    "n_z": 130,
    "dec_n_hiddens": [n_hidden],
    "activation": tf.nn.relu
    }
rnn_type = "gru"  # "lstm", "gru" or "rnn"
model_fn = path.join(output_dir, "lazydynamic_latent_ae.ckpt")

# Model
x = tf.placeholder(TF_DTYPE, [None, None, n_input])
x_lengths = tf.placeholder(TF_ITYPE, [None])
network_dict = tflego.build_encdec_lazydynamic_latentfunc(
    x, x_lengths, n_hidden, build_latent_func,
    latent_func_kwargs, rnn_type=rnn_type
    )
encoder_states = network_dict["encoder_states"]
y = network_dict["decoder_output"]
ae = network_dict["latent_layer"]
mask = network_dict["mask"]
z = ae["z"]

y *= tf.expand_dims(mask, -1)  # safety

# Reconstruction loss
loss = tf.reduce_mean(
    tf.reduce_sum(tf.reduce_mean(tf.square(x - y), -1), -1) /
    tf.reduce_sum(mask, 1)
    )  # https://danijar.com/variable-sequence-lengths-in-tensorflow/

optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

# %%
np.random.seed(1)
train_batch_iterator = SimpleBucketIterator(
    train_x, batch_size, n_buckets, True
    )
val_batch_iterator = SimpleBucketIterator(
    val_x, batch_size, n_buckets, False
    )

record_dict = training.train_fixed_epochs(
    n_epochs, optimizer, loss, train_batch_iterator,
    [x, x_lengths], loss, val_batch_iterator, save_best_val_model_fn=model_fn
    )
# Out:
# 2018-06-11 16:24:23.951344
# Epoch 0:
# 3.408 sec, train loss: 1.01449, val loss: 0.888447 *
# Epoch 1:
# 3.346 sec, train loss: 0.85104, val loss: 0.833312 *
# Epoch 2:
# 3.351 sec, train loss: 0.800598, val loss: 0.792946 *
# Epoch 3:
# 3.347 sec, train loss: 0.764406, val loss: 0.768678 *
# Epoch 4:
# 3.373 sec, train loss: 0.739309, val loss: 0.750783 *
# Epoch 5:
# 3.340 sec, train loss: 0.716643, val loss: 0.730345 *
# Epoch 6:
# 3.339 sec, train loss: 0.690092, val loss: 0.732436
# Epoch 7:
# 3.348 sec, train loss: 0.672479, val loss: 0.702848 *
# Epoch 8:
# 3.350 sec, train loss: 0.655942, val loss: 0.714318
# Epoch 9:
# 3.348 sec, train loss: 0.645904, val loss: 0.680714 *
# Epoch 10:
# 3.349 sec, train loss: 0.631048, val loss: 0.673104 *
# Epoch 11:
# 3.341 sec, train loss: 0.620933, val loss: 0.669629 *
# Epoch 12:
# 3.354 sec, train loss: 0.609651, val loss: 0.663492 *
# Epoch 13:
# 3.375 sec, train loss: 0.60189, val loss: 0.685038
# Epoch 14:
# 3.349 sec, train loss: 0.600993, val loss: 0.68386
# Epoch 15:
# 3.348 sec, train loss: 0.588499, val loss: 0.655056 *
# Epoch 16:
# 3.342 sec, train loss: 0.581148, val loss: 0.663907
# Epoch 17:
# 3.339 sec, train loss: 0.579309, val loss: 0.65392 *
# Epoch 18:
# 3.356 sec, train loss: 0.569445, val loss: 0.639744 *
# Epoch 19:
# 3.349 sec, train loss: 0.558125, val loss: 0.651223
# Epoch 20:
# 3.346 sec, train loss: 0.561051, val loss: 0.643687
# Epoch 21:
# 3.375 sec, train loss: 0.548358, val loss: 0.644451
# Epoch 22:
# 3.373 sec, train loss: 0.544879, val loss: 0.623717 *
# Epoch 23:
# 3.344 sec, train loss: 0.531265, val loss: 0.608342 *
# Epoch 24:
# 3.354 sec, train loss: 0.528765, val loss: 0.626562
# Epoch 25:
# 3.341 sec, train loss: 0.528404, val loss: 0.612116
# Epoch 26:
# 3.350 sec, train loss: 0.517644, val loss: 0.61165
# Epoch 27:
# 3.354 sec, train loss: 0.516582, val loss: 0.614215
# Epoch 28:
# 3.356 sec, train loss: 0.516015, val loss: 0.623797
# Epoch 29:
# 3.340 sec, train loss: 0.508895, val loss: 0.58473 *
# Epoch 30:
# 3.365 sec, train loss: 0.497869, val loss: 0.600751
# Epoch 31:
# 3.336 sec, train loss: 0.49343, val loss: 0.592392
# Epoch 32:
# 3.357 sec, train loss: 0.495432, val loss: 0.587412
# Epoch 33:
# 3.346 sec, train loss: 0.490442, val loss: 0.59691
# Epoch 34:
# 3.334 sec, train loss: 0.484852, val loss: 0.577057 *
# Epoch 35:
# 3.351 sec, train loss: 0.483727, val loss: 0.579147
# Epoch 36:
# 3.347 sec, train loss: 0.476127, val loss: 0.559273 *
# Epoch 37:
# 3.346 sec, train loss: 0.47374, val loss: 0.572168
# Epoch 38:
# 3.343 sec, train loss: 0.466435, val loss: 0.527065 *
# Epoch 39:
# 3.369 sec, train loss: 0.46401, val loss: 0.568382
# Epoch 40:
# 3.340 sec, train loss: 0.467954, val loss: 0.560792
# Epoch 41:
# 3.337 sec, train loss: 0.458561, val loss: 0.535902
# Epoch 42:
# 3.351 sec, train loss: 0.449962, val loss: 0.520021 *
# Epoch 43:
# 3.355 sec, train loss: 0.452398, val loss: 0.549117
# Epoch 44:
# 3.347 sec, train loss: 0.455014, val loss: 0.540646
# Epoch 45:
# 3.347 sec, train loss: 0.447971, val loss: 0.516772 *
# Epoch 46:
# 3.345 sec, train loss: 0.445186, val loss: 0.548704
# Epoch 47:
# 3.347 sec, train loss: 0.454588, val loss: 0.574491
# Epoch 48:
# 3.365 sec, train loss: 0.448421, val loss: 0.532714
# Epoch 49:
# 3.349 sec, train loss: 0.438593, val loss: 0.518267
# Epoch 50:
# 3.345 sec, train loss: 0.436102, val loss: 0.533742
# Epoch 51:
# 3.335 sec, train loss: 0.434397, val loss: 0.504907 *
# Epoch 52:
# 3.345 sec, train loss: 0.425886, val loss: 0.493838 *
# Epoch 53:
# 3.342 sec, train loss: 0.416866, val loss: 0.498321
# Epoch 54:
# 3.355 sec, train loss: 0.416289, val loss: 0.484585 *
# Epoch 55:
# 3.339 sec, train loss: 0.408192, val loss: 0.479365 *
# Epoch 56:
# 3.349 sec, train loss: 0.407542, val loss: 0.480542
# Epoch 57:
# 3.371 sec, train loss: 0.405968, val loss: 0.488171
# Epoch 58:
# 3.343 sec, train loss: 0.404309, val loss: 0.472094 *
# Epoch 59:
# 3.347 sec, train loss: 0.404335, val loss: 0.474706
# Epoch 60:
# 3.348 sec, train loss: 0.399364, val loss: 0.462923 *
# Epoch 61:
# 3.343 sec, train loss: 0.39415, val loss: 0.476006
# Epoch 62:
# 3.345 sec, train loss: 0.393791, val loss: 0.443873 *
# Epoch 63:
# 3.343 sec, train loss: 0.391553, val loss: 0.453483
# Epoch 64:
# 3.344 sec, train loss: 0.388995, val loss: 0.44158 *
# Epoch 65:
# 3.346 sec, train loss: 0.387075, val loss: 0.446386
# Epoch 66:
# 3.361 sec, train loss: 0.387139, val loss: 0.456248
# Epoch 67:
# 3.358 sec, train loss: 0.383516, val loss: 0.443239
# Epoch 68:
# 3.350 sec, train loss: 0.381474, val loss: 0.4336 *
# Epoch 69:
# 3.346 sec, train loss: 0.384901, val loss: 0.459308
# Epoch 70:
# 3.342 sec, train loss: 0.376936, val loss: 0.442228
# Epoch 71:
# 3.356 sec, train loss: 0.376593, val loss: 0.445935
# Epoch 72:
# 3.341 sec, train loss: 0.373062, val loss: 0.437964
# Epoch 73:
# 3.349 sec, train loss: 0.382507, val loss: 0.440693
# Epoch 74:
# 3.345 sec, train loss: 0.366356, val loss: 0.427596 *
# Epoch 75:
# 3.387 sec, train loss: 0.371237, val loss: 0.419884 *
# Epoch 76:
# 3.350 sec, train loss: 0.369256, val loss: 0.430606
# Epoch 77:
# 3.340 sec, train loss: 0.36937, val loss: 0.429917
# Epoch 78:
# 3.339 sec, train loss: 0.362346, val loss: 0.430851
# Epoch 79:
# 3.347 sec, train loss: 0.365658, val loss: 0.417163 *
# Epoch 80:
# 3.355 sec, train loss: 0.360639, val loss: 0.417535
# Epoch 81:
# 3.377 sec, train loss: 0.362982, val loss: 0.417191
# Epoch 82:
# 3.348 sec, train loss: 0.356374, val loss: 0.408462 *
# Epoch 83:
# 3.344 sec, train loss: 0.35602, val loss: 0.410774
# Epoch 84:
# 3.359 sec, train loss: 0.354505, val loss: 0.420027
# Epoch 85:
# 3.345 sec, train loss: 0.354427, val loss: 0.406696 *
# Epoch 86:
# 3.347 sec, train loss: 0.353671, val loss: 0.407676
# Epoch 87:
# 3.345 sec, train loss: 0.353293, val loss: 0.418152
# Epoch 88:
# 3.364 sec, train loss: 0.348398, val loss: 0.409663
# Epoch 89:
# 3.350 sec, train loss: 0.349285, val loss: 0.396466 *
# Epoch 90:
# 3.362 sec, train loss: 0.345675, val loss: 0.395194 *
# Epoch 91:
# 3.345 sec, train loss: 0.341152, val loss: 0.394711 *
# Epoch 92:
# 3.367 sec, train loss: 0.345052, val loss: 0.394728
# Epoch 93:
# 3.350 sec, train loss: 0.345671, val loss: 0.402405
# Epoch 94:
# 3.352 sec, train loss: 0.341623, val loss: 0.395156
# Epoch 95:
# 3.345 sec, train loss: 0.341557, val loss: 0.395475
# Epoch 96:
# 3.347 sec, train loss: 0.338024, val loss: 0.392787 *
# Epoch 97:
# 3.360 sec, train loss: 0.338019, val loss: 0.388771 *
# Epoch 98:
# 3.343 sec, train loss: 0.33519, val loss: 0.396248
# Epoch 99:
# 3.354 sec, train loss: 0.336698, val loss: 0.40464
# Epoch 100:
# 3.340 sec, train loss: 0.334729, val loss: 0.382057 *
# Epoch 101:
# 3.364 sec, train loss: 0.332025, val loss: 0.379405 *
# Epoch 102:
# 3.340 sec, train loss: 0.330763, val loss: 0.379798
# Epoch 103:
# 3.346 sec, train loss: 0.333304, val loss: 0.395835
# Epoch 104:
# 3.340 sec, train loss: 0.328214, val loss: 0.385606
# Epoch 105:
# 3.337 sec, train loss: 0.331383, val loss: 0.383628
# Epoch 106:
# 3.342 sec, train loss: 0.328586, val loss: 0.386614
# Epoch 107:
# 3.347 sec, train loss: 0.327058, val loss: 0.386109
# Epoch 108:
# 3.337 sec, train loss: 0.325601, val loss: 0.381916
# Epoch 109:
# 3.347 sec, train loss: 0.323534, val loss: 0.383494
# Epoch 110:
# 3.374 sec, train loss: 0.322597, val loss: 0.367602 *
# Epoch 111:
# 3.355 sec, train loss: 0.31902, val loss: 0.371239
# Epoch 112:
# 3.346 sec, train loss: 0.323873, val loss: 0.394519
# Epoch 113:
# 3.334 sec, train loss: 0.32254, val loss: 0.365425 *
# Epoch 114:
# 3.347 sec, train loss: 0.317377, val loss: 0.390826
# Epoch 115:
# 3.346 sec, train loss: 0.315679, val loss: 0.361601 *
# Epoch 116:
# 3.338 sec, train loss: 0.310258, val loss: 0.355879 *
# Epoch 117:
# 3.351 sec, train loss: 0.310342, val loss: 0.3622
# Epoch 118:
# 3.351 sec, train loss: 0.310216, val loss: 0.360901
# Epoch 119:
# 3.363 sec, train loss: 0.309818, val loss: 0.356557
# Epoch 120:
# 3.347 sec, train loss: 0.31061, val loss: 0.366016
# Epoch 121:
# 3.346 sec, train loss: 0.309462, val loss: 0.361928
# Epoch 122:
# 3.351 sec, train loss: 0.310964, val loss: 0.370314
# Epoch 123:
# 3.347 sec, train loss: 0.305579, val loss: 0.354869 *
# Epoch 124:
# 3.338 sec, train loss: 0.306012, val loss: 0.369389
# Epoch 125:
# 3.348 sec, train loss: 0.313213, val loss: 0.371704
# Epoch 126:
# 3.342 sec, train loss: 0.306212, val loss: 0.353408 *
# Epoch 127:
# 3.339 sec, train loss: 0.304934, val loss: 0.356033
# Epoch 128:
# 3.370 sec, train loss: 0.300785, val loss: 0.351966 *
# Epoch 129:
# 3.349 sec, train loss: 0.310472, val loss: 0.367199
# Epoch 130:
# 3.343 sec, train loss: 0.298997, val loss: 0.349537 *
# Epoch 131:
# 3.342 sec, train loss: 0.302406, val loss: 0.355593
# Epoch 132:
# 3.351 sec, train loss: 0.303564, val loss: 0.35909
# Epoch 133:
# 3.342 sec, train loss: 0.297928, val loss: 0.345587 *
# Epoch 134:
# 3.348 sec, train loss: 0.298608, val loss: 0.349435
# Epoch 135:
# 3.342 sec, train loss: 0.30408, val loss: 0.366871
# Epoch 136:
# 3.350 sec, train loss: 0.299246, val loss: 0.346436
# Epoch 137:
# 3.381 sec, train loss: 0.303296, val loss: 0.362227
# Epoch 138:
# 3.343 sec, train loss: 0.29381, val loss: 0.346239
# Epoch 139:
# 3.347 sec, train loss: 0.299475, val loss: 0.349306
# Epoch 140:
# 3.349 sec, train loss: 0.294451, val loss: 0.351903
# Epoch 141:
# 3.348 sec, train loss: 0.304004, val loss: 0.362611
# Epoch 142:
# 3.353 sec, train loss: 0.290843, val loss: 0.340219 *
# Epoch 143:
# 3.351 sec, train loss: 0.293093, val loss: 0.3596
# Epoch 144:
# 3.349 sec, train loss: 0.291898, val loss: 0.34106
# Epoch 145:
# 3.347 sec, train loss: 0.289638, val loss: 0.340512
# Epoch 146:
# 3.363 sec, train loss: 0.294513, val loss: 0.352436
# Epoch 147:
# 3.347 sec, train loss: 0.285707, val loss: 0.342148
# Epoch 148:
# 3.349 sec, train loss: 0.288015, val loss: 0.343752
# Epoch 149:
# 3.345 sec, train loss: 0.291171, val loss: 0.34864
# Epoch 150:
# 3.345 sec, train loss: 0.289967, val loss: 0.338198 *
# Epoch 151:
# 3.350 sec, train loss: 0.292821, val loss: 0.347645
# Epoch 152:
# 3.350 sec, train loss: 0.284597, val loss: 0.332891 *
# Epoch 153:
# 3.350 sec, train loss: 0.282702, val loss: 0.331117 *
# Epoch 154:
# 3.334 sec, train loss: 0.290762, val loss: 0.364652
# Epoch 155:
# 3.373 sec, train loss: 0.289256, val loss: 0.333877
# Epoch 156:
# 3.350 sec, train loss: 0.288754, val loss: 0.352782
# Epoch 157:
# 3.347 sec, train loss: 0.281368, val loss: 0.332222
# Epoch 158:
# 3.347 sec, train loss: 0.279222, val loss: 0.333557
# Epoch 159:
# 3.338 sec, train loss: 0.283065, val loss: 0.333654
# Epoch 160:
# 3.352 sec, train loss: 0.283163, val loss: 0.333445
# Epoch 161:
# 3.345 sec, train loss: 0.284548, val loss: 0.336779
# Epoch 162:
# 3.345 sec, train loss: 0.279551, val loss: 0.328113 *
# Epoch 163:
# 3.349 sec, train loss: 0.280817, val loss: 0.333474
# Epoch 164:
# 3.358 sec, train loss: 0.287971, val loss: 0.34723
# Epoch 165:
# 3.354 sec, train loss: 0.279868, val loss: 0.324825 *
# Epoch 166:
# 3.352 sec, train loss: 0.277571, val loss: 0.330275
# Epoch 167:
# 3.355 sec, train loss: 0.281933, val loss: 0.336872
# Epoch 168:
# 3.348 sec, train loss: 0.278062, val loss: 0.329387
# Epoch 169:
# 3.340 sec, train loss: 0.282378, val loss: 0.337962
# Epoch 170:
# 3.350 sec, train loss: 0.277961, val loss: 0.325252
# Epoch 171:
# 3.357 sec, train loss: 0.281704, val loss: 0.332635
# Epoch 172:
# 3.363 sec, train loss: 0.270944, val loss: 0.321631 *
# Epoch 173:
# 3.372 sec, train loss: 0.272758, val loss: 0.317895 *
# Epoch 174:
# 3.364 sec, train loss: 0.273232, val loss: 0.326329
# Epoch 175:
# 3.343 sec, train loss: 0.274643, val loss: 0.327361
# Epoch 176:
# 3.338 sec, train loss: 0.277773, val loss: 0.33084
# Epoch 177:
# 3.349 sec, train loss: 0.272122, val loss: 0.319001
# Epoch 178:
# 3.343 sec, train loss: 0.276943, val loss: 0.338977
# Epoch 179:
# 3.350 sec, train loss: 0.274881, val loss: 0.32091
# Epoch 180:
# 3.347 sec, train loss: 0.270812, val loss: 0.325304
# Epoch 181:
# 3.361 sec, train loss: 0.272283, val loss: 0.321917
# Epoch 182:
# 3.350 sec, train loss: 0.274874, val loss: 0.341179
# Epoch 183:
# 3.339 sec, train loss: 0.269211, val loss: 0.316885 *
# Epoch 184:
# 3.356 sec, train loss: 0.270145, val loss: 0.320748
# Epoch 185:
# 3.345 sec, train loss: 0.270954, val loss: 0.322348
# Epoch 186:
# 3.352 sec, train loss: 0.26925, val loss: 0.319262
# Epoch 187:
# 3.349 sec, train loss: 0.271849, val loss: 0.325199
# Epoch 188:
# 3.366 sec, train loss: 0.262702, val loss: 0.311013 *
# Epoch 189:
# 3.359 sec, train loss: 0.26862, val loss: 0.334085
# Epoch 190:
# 3.362 sec, train loss: 0.271774, val loss: 0.316088
# Epoch 191:
# 3.349 sec, train loss: 0.267217, val loss: 0.327493
# Epoch 192:
# 3.356 sec, train loss: 0.264156, val loss: 0.310374 *
# Epoch 193:
# 3.345 sec, train loss: 0.263175, val loss: 0.307995 *
# Epoch 194:
# 3.351 sec, train loss: 0.265715, val loss: 0.319074
# Epoch 195:
# 3.351 sec, train loss: 0.264803, val loss: 0.316606
# Epoch 196:
# 3.348 sec, train loss: 0.27021, val loss: 0.321204
# Epoch 197:
# 3.343 sec, train loss: 0.261429, val loss: 0.306582 *
# Epoch 198:
# 3.347 sec, train loss: 0.260103, val loss: 0.311004
# Epoch 199:
# 3.366 sec, train loss: 0.264118, val loss: 0.313648
# Epoch 200:
# 3.343 sec, train loss: 0.262971, val loss: 0.315565
# Epoch 201:
# 3.352 sec, train loss: 0.263408, val loss: 0.315059
# Epoch 202:
# 3.345 sec, train loss: 0.262335, val loss: 0.30944
# Epoch 203:
# 3.352 sec, train loss: 0.26306, val loss: 0.318784
# Epoch 204:
# 3.351 sec, train loss: 0.266701, val loss: 0.321672
# Epoch 205:
# 3.343 sec, train loss: 0.26031, val loss: 0.309506
# Epoch 206:
# 3.356 sec, train loss: 0.263623, val loss: 0.312765
# Epoch 207:
# 3.347 sec, train loss: 0.259499, val loss: 0.306022 *
# Epoch 208:
# 3.354 sec, train loss: 0.259435, val loss: 0.308449
# Epoch 209:
# 3.346 sec, train loss: 0.256314, val loss: 0.305264 *
# Epoch 210:
# 3.364 sec, train loss: 0.258447, val loss: 0.312532
# Epoch 211:
# 3.354 sec, train loss: 0.263226, val loss: 0.317125
# Epoch 212:
# 3.353 sec, train loss: 0.259537, val loss: 0.305215 *
# Epoch 213:
# 3.346 sec, train loss: 0.258337, val loss: 0.310679
# Epoch 214:
# 3.346 sec, train loss: 0.262525, val loss: 0.312861
# Epoch 215:
# 3.348 sec, train loss: 0.254727, val loss: 0.302596 *
# Epoch 216:
# 3.348 sec, train loss: 0.257281, val loss: 0.302457 *
# Epoch 217:
# 3.355 sec, train loss: 0.254311, val loss: 0.300628 *
# Epoch 218:
# 3.355 sec, train loss: 0.252204, val loss: 0.297091 *
# Epoch 219:
# 3.341 sec, train loss: 0.250598, val loss: 0.300248
# Epoch 220:
# 3.346 sec, train loss: 0.252374, val loss: 0.300288
# Epoch 221:
# 3.340 sec, train loss: 0.256079, val loss: 0.305177
# Epoch 222:
# 3.344 sec, train loss: 0.255475, val loss: 0.298192
# Epoch 223:
# 3.346 sec, train loss: 0.25638, val loss: 0.322418
# Epoch 224:
# 3.347 sec, train loss: 0.253579, val loss: 0.298698
# Epoch 225:
# 3.344 sec, train loss: 0.245438, val loss: 0.294352 *
# Epoch 226:
# 3.371 sec, train loss: 0.245329, val loss: 0.294653
# Epoch 227:
# 3.344 sec, train loss: 0.244445, val loss: 0.296784
# Epoch 228:
# 3.355 sec, train loss: 0.244358, val loss: 0.298489
# Epoch 229:
# 3.346 sec, train loss: 0.243441, val loss: 0.293641 *
# Epoch 230:
# 3.352 sec, train loss: 0.241784, val loss: 0.290524 *
# Epoch 231:
# 3.351 sec, train loss: 0.243957, val loss: 0.291371
# Epoch 232:
# 3.342 sec, train loss: 0.241392, val loss: 0.289128 *
# Epoch 233:
# 3.349 sec, train loss: 0.243521, val loss: 0.301087
# Epoch 234:
# 3.352 sec, train loss: 0.242187, val loss: 0.289401
# Epoch 235:
# 3.367 sec, train loss: 0.242036, val loss: 0.287481 *
# Epoch 236:
# 3.349 sec, train loss: 0.242844, val loss: 0.287678
# Epoch 237:
# 3.344 sec, train loss: 0.241353, val loss: 0.286633 *
# Epoch 238:
# 3.355 sec, train loss: 0.239892, val loss: 0.286661
# Epoch 239:
# 3.345 sec, train loss: 0.239367, val loss: 0.285135 *
# Epoch 240:
# 3.353 sec, train loss: 0.238305, val loss: 0.284397 *
# Epoch 241:
# 3.354 sec, train loss: 0.238887, val loss: 0.283112 *
# Epoch 242:
# 3.347 sec, train loss: 0.239194, val loss: 0.283614
# Epoch 243:
# 3.345 sec, train loss: 0.238119, val loss: 0.282934 *
# Epoch 244:
# 3.357 sec, train loss: 0.240402, val loss: 0.282977
# Epoch 245:
# 3.344 sec, train loss: 0.23959, val loss: 0.286327
# Epoch 246:
# 3.353 sec, train loss: 0.238061, val loss: 0.282603 *
# Epoch 247:
# 3.344 sec, train loss: 0.241958, val loss: 0.286232
# Epoch 248:
# 3.357 sec, train loss: 0.23983, val loss: 0.280888 *
# Epoch 249:
# 3.346 sec, train loss: 0.236678, val loss: 0.283371
# Epoch 250:
# 3.352 sec, train loss: 0.240302, val loss: 0.283009
# Epoch 251:
# 3.354 sec, train loss: 0.234995, val loss: 0.278959 *
# Epoch 252:
# 3.361 sec, train loss: 0.237108, val loss: 0.281399
# Epoch 253:
# 3.346 sec, train loss: 0.234766, val loss: 0.279381
# Epoch 254:
# 3.346 sec, train loss: 0.234339, val loss: 0.279585
# Epoch 255:
# 3.353 sec, train loss: 0.236743, val loss: 0.278501 *
# Epoch 256:
# 3.344 sec, train loss: 0.234551, val loss: 0.280929
# Epoch 257:
# 3.347 sec, train loss: 0.242586, val loss: 0.281289
# Epoch 258:
# 3.371 sec, train loss: 0.233552, val loss: 0.279516
# Epoch 259:
# 3.361 sec, train loss: 0.236072, val loss: 0.278672
# Epoch 260:
# 3.342 sec, train loss: 0.234609, val loss: 0.277428 *
# Epoch 261:
# 3.348 sec, train loss: 0.235648, val loss: 0.278374
# Epoch 262:
# 3.353 sec, train loss: 0.23399, val loss: 0.275508 *
# Epoch 263:
# 3.353 sec, train loss: 0.232293, val loss: 0.275557
# Epoch 264:
# 3.337 sec, train loss: 0.234673, val loss: 0.274859 *
# Epoch 265:
# 3.358 sec, train loss: 0.232822, val loss: 0.275779
# Epoch 266:
# 3.347 sec, train loss: 0.236712, val loss: 0.276639
# Epoch 267:
# 3.350 sec, train loss: 0.23522, val loss: 0.278484
# Epoch 268:
# 3.356 sec, train loss: 0.23263, val loss: 0.280498
# Epoch 269:
# 3.348 sec, train loss: 0.230234, val loss: 0.27228 *
# Epoch 270:
# 3.361 sec, train loss: 0.228015, val loss: 0.27313
# Epoch 271:
# 3.331 sec, train loss: 0.229726, val loss: 0.272971
# Epoch 272:
# 3.338 sec, train loss: 0.229827, val loss: 0.272597
# Epoch 273:
# 3.348 sec, train loss: 0.231973, val loss: 0.274197
# Epoch 274:
# 3.351 sec, train loss: 0.232397, val loss: 0.273908
# Epoch 275:
# 3.346 sec, train loss: 0.23089, val loss: 0.284122
# Epoch 276:
# 3.352 sec, train loss: 0.232107, val loss: 0.272694
# Epoch 277:
# 3.346 sec, train loss: 0.230493, val loss: 0.272475
# Epoch 278:
# 3.352 sec, train loss: 0.229908, val loss: 0.271453 *
# Epoch 279:
# 3.372 sec, train loss: 0.2272, val loss: 0.271637
# Epoch 280:
# 3.345 sec, train loss: 0.227252, val loss: 0.270214 *
# Epoch 281:
# 3.360 sec, train loss: 0.224402, val loss: 0.269477 *
# Epoch 282:
# 3.338 sec, train loss: 0.22732, val loss: 0.27097
# Epoch 283:
# 3.342 sec, train loss: 0.227633, val loss: 0.273934
# Epoch 284:
# 3.350 sec, train loss: 0.22478, val loss: 0.269386 *
# Epoch 285:
# 3.356 sec, train loss: 0.22654, val loss: 0.268416 *
# Epoch 286:
# 3.346 sec, train loss: 0.227553, val loss: 0.269311
# Epoch 287:
# 3.346 sec, train loss: 0.224182, val loss: 0.268025 *
# Epoch 288:
# 3.366 sec, train loss: 0.225228, val loss: 0.267171 *
# Epoch 289:
# 3.343 sec, train loss: 0.228971, val loss: 0.273809
# Epoch 290:
# 3.343 sec, train loss: 0.225894, val loss: 0.26658 *
# Epoch 291:
# 3.339 sec, train loss: 0.225224, val loss: 0.267177
# Epoch 292:
# 3.353 sec, train loss: 0.226834, val loss: 0.266508 *
# Epoch 293:
# 3.354 sec, train loss: 0.225481, val loss: 0.270065
# Epoch 294:
# 3.351 sec, train loss: 0.224705, val loss: 0.269619
# Epoch 295:
# 3.347 sec, train loss: 0.225303, val loss: 0.266815
# Epoch 296:
# 3.353 sec, train loss: 0.224191, val loss: 0.26315 *
# Epoch 297:
# 3.366 sec, train loss: 0.221604, val loss: 0.265843
# Epoch 298:
# 3.332 sec, train loss: 0.222503, val loss: 0.261537 *
# Epoch 299:
# 3.344 sec, train loss: 0.221909, val loss: 0.263215
# Epoch 300:
# 3.355 sec, train loss: 0.219326, val loss: 0.26074 *
# Epoch 301:
# 3.347 sec, train loss: 0.217984, val loss: 0.26166
# Epoch 302:
# 3.350 sec, train loss: 0.218508, val loss: 0.261889
# Epoch 303:
# 3.339 sec, train loss: 0.220693, val loss: 0.266361
# Epoch 304:
# 3.346 sec, train loss: 0.226987, val loss: 0.266232
# Epoch 305:
# 3.352 sec, train loss: 0.218543, val loss: 0.26102
# Epoch 306:
# 3.358 sec, train loss: 0.220068, val loss: 0.263554
# Epoch 307:
# 3.348 sec, train loss: 0.226478, val loss: 0.269592
# Epoch 308:
# 3.344 sec, train loss: 0.217605, val loss: 0.265018
# Epoch 309:
# 3.338 sec, train loss: 0.221961, val loss: 0.263113
# Epoch 310:
# 3.340 sec, train loss: 0.224678, val loss: 0.262604
# Epoch 311:
# 3.348 sec, train loss: 0.218602, val loss: 0.260649 *
# Epoch 312:
# 3.358 sec, train loss: 0.218655, val loss: 0.260379 *
# Epoch 313:
# 3.348 sec, train loss: 0.221623, val loss: 0.260146 *
# Epoch 314:
# 3.350 sec, train loss: 0.217063, val loss: 0.258853 *
# Epoch 315:
# 3.374 sec, train loss: 0.217701, val loss: 0.260361
# Epoch 316:
# 3.348 sec, train loss: 0.218261, val loss: 0.258249 *
# Epoch 317:
# 3.344 sec, train loss: 0.21539, val loss: 0.257777 *
# Epoch 318:
# 3.355 sec, train loss: 0.217184, val loss: 0.262028
# Epoch 319:
# 3.346 sec, train loss: 0.221296, val loss: 0.259947
# Epoch 320:
# 3.358 sec, train loss: 0.21826, val loss: 0.258812
# Epoch 321:
# 3.355 sec, train loss: 0.217609, val loss: 0.259088
# Epoch 322:
# 3.337 sec, train loss: 0.219802, val loss: 0.260806
# Epoch 323:
# 3.358 sec, train loss: 0.21864, val loss: 0.259204
# Epoch 324:
# 3.354 sec, train loss: 0.215474, val loss: 0.259766
# Epoch 325:
# 3.348 sec, train loss: 0.214139, val loss: 0.255577 *
# Epoch 326:
# 3.343 sec, train loss: 0.215761, val loss: 0.256444
# Epoch 327:
# 3.349 sec, train loss: 0.213425, val loss: 0.255325 *
# Epoch 328:
# 3.342 sec, train loss: 0.214287, val loss: 0.256227
# Epoch 329:
# 3.351 sec, train loss: 0.216338, val loss: 0.259948
# Epoch 330:
# 3.361 sec, train loss: 0.215645, val loss: 0.255943
# Epoch 331:
# 3.353 sec, train loss: 0.218582, val loss: 0.261928
# Epoch 332:
# 3.365 sec, train loss: 0.212539, val loss: 0.252844 *
# Epoch 333:
# 3.349 sec, train loss: 0.211134, val loss: 0.25341
# Epoch 334:
# 3.348 sec, train loss: 0.212143, val loss: 0.255638
# Epoch 335:
# 3.334 sec, train loss: 0.214704, val loss: 0.25507
# Epoch 336:
# 3.361 sec, train loss: 0.210797, val loss: 0.254561
# Epoch 337:
# 3.346 sec, train loss: 0.213539, val loss: 0.257769
# Epoch 338:
# 3.342 sec, train loss: 0.214975, val loss: 0.255497
# Epoch 339:
# 3.350 sec, train loss: 0.219851, val loss: 0.257322
# Epoch 340:
# 3.350 sec, train loss: 0.213608, val loss: 0.254403
# Epoch 341:
# 3.362 sec, train loss: 0.211667, val loss: 0.251635 *
# Epoch 342:
# 3.354 sec, train loss: 0.209992, val loss: 0.255769
# Epoch 343:
# 3.348 sec, train loss: 0.21101, val loss: 0.251703
# Epoch 344:
# 3.349 sec, train loss: 0.210284, val loss: 0.252064
# Epoch 345:
# 3.345 sec, train loss: 0.209681, val loss: 0.253657
# Epoch 346:
# 3.349 sec, train loss: 0.214549, val loss: 0.25468
# Epoch 347:
# 3.345 sec, train loss: 0.209668, val loss: 0.250924 *
# Epoch 348:
# 3.362 sec, train loss: 0.210071, val loss: 0.254296
# Epoch 349:
# 3.349 sec, train loss: 0.215238, val loss: 0.254866
# Epoch 350:
# 3.358 sec, train loss: 0.210411, val loss: 0.2527
# Epoch 351:
# 3.354 sec, train loss: 0.211278, val loss: 0.250889 *
# Epoch 352:
# 3.355 sec, train loss: 0.213295, val loss: 0.257636
# Epoch 353:
# 3.348 sec, train loss: 0.212464, val loss: 0.252391
# Epoch 354:
# 3.342 sec, train loss: 0.210773, val loss: 0.261014
# Epoch 355:
# 3.344 sec, train loss: 0.21028, val loss: 0.251086
# Epoch 356:
# 3.347 sec, train loss: 0.211167, val loss: 0.249394 *
# Epoch 357:
# 3.356 sec, train loss: 0.208428, val loss: 0.250505
# Epoch 358:
# 3.341 sec, train loss: 0.209838, val loss: 0.250793
# Epoch 359:
# 3.367 sec, train loss: 0.207272, val loss: 0.248034 *
# Epoch 360:
# 3.343 sec, train loss: 0.2079, val loss: 0.249128
# Epoch 361:
# 3.349 sec, train loss: 0.211847, val loss: 0.267041
# Epoch 362:
# 3.354 sec, train loss: 0.210388, val loss: 0.247653 *
# Epoch 363:
# 3.349 sec, train loss: 0.20691, val loss: 0.250286
# Epoch 364:
# 3.351 sec, train loss: 0.211369, val loss: 0.250258
# Epoch 365:
# 3.351 sec, train loss: 0.204552, val loss: 0.247541 *
# Epoch 366:
# 3.351 sec, train loss: 0.205579, val loss: 0.246294 *
# Epoch 367:
# 3.336 sec, train loss: 0.202965, val loss: 0.24641
# Epoch 368:
# 3.367 sec, train loss: 0.203185, val loss: 0.247234
# Epoch 369:
# 3.348 sec, train loss: 0.203639, val loss: 0.247787
# Epoch 370:
# 3.337 sec, train loss: 0.203048, val loss: 0.246943
# Epoch 371:
# 3.353 sec, train loss: 0.203524, val loss: 0.245181 *
# Epoch 372:
# 3.350 sec, train loss: 0.203754, val loss: 0.25354
# Epoch 373:
# 3.355 sec, train loss: 0.205038, val loss: 0.245767
# Epoch 374:
# 3.346 sec, train loss: 0.206122, val loss: 0.249632
# Epoch 375:
# 3.344 sec, train loss: 0.20367, val loss: 0.246467
# Epoch 376:
# 3.344 sec, train loss: 0.202176, val loss: 0.245152 *
# Epoch 377:
# 3.382 sec, train loss: 0.201781, val loss: 0.24363 *
# Epoch 378:
# 3.345 sec, train loss: 0.203755, val loss: 0.249042
# Epoch 379:
# 3.353 sec, train loss: 0.204082, val loss: 0.245577
# Epoch 380:
# 3.346 sec, train loss: 0.212551, val loss: 0.253815
# Epoch 381:
# 3.350 sec, train loss: 0.211254, val loss: 0.245865
# Epoch 382:
# 3.349 sec, train loss: 0.203393, val loss: 0.245678
# Epoch 383:
# 3.347 sec, train loss: 0.20144, val loss: 0.245268
# Epoch 384:
# 3.349 sec, train loss: 0.200435, val loss: 0.247804
# Epoch 385:
# 3.344 sec, train loss: 0.202515, val loss: 0.245888
# Epoch 386:
# 3.377 sec, train loss: 0.201377, val loss: 0.24823
# Epoch 387:
# 3.344 sec, train loss: 0.201311, val loss: 0.244324
# Epoch 388:
# 3.350 sec, train loss: 0.202728, val loss: 0.246071
# Epoch 389:
# 3.344 sec, train loss: 0.200198, val loss: 0.242043 *
# Epoch 390:
# 3.356 sec, train loss: 0.200354, val loss: 0.241597 *
# Epoch 391:
# 3.342 sec, train loss: 0.199378, val loss: 0.245131
# Epoch 392:
# 3.345 sec, train loss: 0.199567, val loss: 0.240867 *
# Epoch 393:
# 3.345 sec, train loss: 0.199114, val loss: 0.241047
# Epoch 394:
# 3.351 sec, train loss: 0.200611, val loss: 0.244034
# Epoch 395:
# 3.360 sec, train loss: 0.211188, val loss: 0.252393
# Epoch 396:
# 3.337 sec, train loss: 0.205298, val loss: 0.244945
# Epoch 397:
# 3.353 sec, train loss: 0.19944, val loss: 0.245866
# Epoch 398:
# 3.347 sec, train loss: 0.199505, val loss: 0.242006
# Epoch 399:
# 3.353 sec, train loss: 0.203956, val loss: 0.246236
# Training time: 22.334 min
# 2018-06-11 16:46:54.785207

# %%
# Embed validation
val_batch_iterator = SimpleIterator(
    val_x, len(val_x), False
    )
labels = [val_labels[i] for i in val_batch_iterator.indices]
saver = tf.train.Saver()
with tf.Session() as session:
    saver.restore(session, model_fn)
    for batch_x_padded, batch_x_lengths in val_batch_iterator:
        np_x = batch_x_padded
        np_x_lengths = batch_x_lengths
        np_z = session.run(
            [z], feed_dict={x: np_x, x_lengths: np_x_lengths}
            )[0]
        np_y = session.run(
            [y], feed_dict={x: np_x, x_lengths: np_x_lengths}
            )[0]
        break  # single batch

embed_dict = {}
for i, utt_key in enumerate([val_keys[i] for i in val_batch_iterator.indices]):
    embed_dict[utt_key] = np_z[i]
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/lazydynamic_latent_ae.ckpt

# %%
# Same-different evaluation
distances = pdist(np_z, metric="cosine")
matches = samediff.generate_matches_array(labels)
ap, prb = samediff.average_precision(
    distances[matches == True], distances[matches == False]
    )

print("Average precision: {:.4f}".format(ap))
print("Precision-recall breakeven: {:.4f}".format(prb))
# Out:
# Average precision: 0.1979
# Precision-recall breakeven: 0.2445

# %%
# Plot reconstruction
plt.figure(figsize=(12, 8))
for i in range(5):
    plt.subplot(5, 2, 2*i + 1)
    if i == 0:
        plt.title("Input")
    plt.imshow(np_x[i][:np_x_lengths[i]].T)
    plt.axis("off")
    plt.subplot(5, 2, 2*i + 2)
    if i == 0:
        plt.title("Reconstruction")
    plt.imshow(np_y[i][:np_x_lengths[i]].T)
    plt.axis("off")

# %%
plotting.plot_raw_embeds(
    embed_dict, ["because", "yknow", "people", "something", "anything", "education", "situation"],
    figsize=(12, 8)
    )

# %% [markdown]
# ## Autoencoder with latent transformation and Bernoulli log-loss

# %%
tf.reset_default_graph()

# Training parameters
learning_rate = 0.001
n_epochs = 20  # 50
batch_size = 100
n_buckets = 3

# Model parameters
n_input = d_frame
n_hidden = 150
build_latent_func = tflego.build_autoencoder
latent_func_kwargs = {
    "enc_n_hiddens": [],
    "n_z": 130,
    "dec_n_hiddens": [n_hidden],
    "activation": tf.nn.relu
    }
rnn_type = "gru"  # "lstm", "gru" or "rnn"
model_fn = path.join(output_dir, "lazydynamic_latent_ae.ckpt")

# Model
x = tf.placeholder(TF_DTYPE, [None, None, n_input])
x_lengths = tf.placeholder(TF_ITYPE, [None])
network_dict = tflego.build_encdec_lazydynamic_latentfunc(
    x, x_lengths, n_hidden, build_latent_func,
    latent_func_kwargs, rnn_type=rnn_type
    )
encoder_states = network_dict["encoder_states"]
y = network_dict["decoder_output"]
ae = network_dict["latent_layer"]
mask = network_dict["mask"]
z = ae["z"]

y = tf.nn.sigmoid(y)
y *= tf.expand_dims(mask, -1)  # safety

# Reconstruction loss
log_loss = x*tf.log(1e-10 + y) + (1 - x)*tf.log(1e-10 + 1 - y)
reconstruction_loss = -tf.reduce_sum(log_loss, -1)
reconstruction_loss *= mask  # safety
reconstruction_loss = tf.reduce_sum(reconstruction_loss, -1) / tf.reduce_sum(mask, 1)
reconstruction_loss = tf.reduce_mean(reconstruction_loss) # https://danijar.com/variable-sequence-lengths-in-tensorflow/
loss = reconstruction_loss
# loss = tf.reduce_mean(
#     tf.reduce_sum(tf.reduce_mean(tf.square(x - y), -1), -1) /
#     tf.reduce_sum(mask, 1)
#     )  # https://danijar.com/variable-sequence-lengths-in-tensorflow/

optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

# %%
np.random.seed(1)
train_batch_iterator = SimpleBucketIterator(
    train_x_scaled, batch_size, n_buckets, True
    )
val_batch_iterator = SimpleBucketIterator(
    val_x_scaled, batch_size, n_buckets, False
    )

record_dict = training.train_fixed_epochs(
    n_epochs, optimizer, loss, train_batch_iterator,
    [x, x_lengths], loss, val_batch_iterator, save_best_val_model_fn=model_fn
    )
# Out:
# 2018-08-08 10:23:50.044267
# Epoch 0:
# 3.447 sec, train loss: 9.01523, val loss: 8.96196 *
# Epoch 1:
# 3.387 sec, train loss: 8.95871, val loss: 8.95301 *
# Epoch 2:
# 3.404 sec, train loss: 8.94554, val loss: 8.94201 *
# Epoch 3:
# 3.391 sec, train loss: 8.93749, val loss: 8.93707 *
# Epoch 4:
# 3.401 sec, train loss: 8.93295, val loss: 8.93317 *
# Epoch 5:
# 3.386 sec, train loss: 8.92864, val loss: 8.92957 *
# Epoch 6:
# 3.396 sec, train loss: 8.92578, val loss: 8.9262 *
# Epoch 7:
# 3.395 sec, train loss: 8.92174, val loss: 8.92281 *
# Epoch 8:
# 3.395 sec, train loss: 8.91799, val loss: 8.92022 *
# Epoch 9:
# 3.398 sec, train loss: 8.91484, val loss: 8.92 *
# Epoch 10:
# 3.385 sec, train loss: 8.91282, val loss: 8.9164 *
# Epoch 11:
# 3.394 sec, train loss: 8.90925, val loss: 8.91547 *
# Epoch 12:
# 3.390 sec, train loss: 8.90814, val loss: 8.91389 *
# Epoch 13:
# 3.391 sec, train loss: 8.90664, val loss: 8.91455
# Epoch 14:
# 3.392 sec, train loss: 8.90589, val loss: 8.91202 *
# Epoch 15:
# 3.396 sec, train loss: 8.90473, val loss: 8.91122 *
# Epoch 16:
# 3.400 sec, train loss: 8.90336, val loss: 8.90981 *
# Epoch 17:
# 3.392 sec, train loss: 8.90194, val loss: 8.90784 *
# Epoch 18:
# 3.391 sec, train loss: 8.90061, val loss: 8.909
# Epoch 19:
# 3.387 sec, train loss: 8.89932, val loss: 8.9058 *
# Training time: 1.132 min
# 2018-08-08 10:24:59.738209

# %%
# Embed validation
val_batch_iterator = SimpleIterator(
    val_x_scaled, len(val_x), False
    )
labels = [val_labels[i] for i in val_batch_iterator.indices]
saver = tf.train.Saver()
with tf.Session() as session:
    saver.restore(session, model_fn)
    for batch_x_padded, batch_x_lengths in val_batch_iterator:
        np_x = batch_x_padded
        np_x_lengths = batch_x_lengths
        np_z = session.run(
            [z], feed_dict={x: np_x, x_lengths: np_x_lengths}
            )[0]
        np_y = session.run(
            [y], feed_dict={x: np_x, x_lengths: np_x_lengths}
            )[0]
        break  # single batch

embed_dict = {}
for i, utt_key in enumerate([val_keys[i] for i in val_batch_iterator.indices]):
    embed_dict[utt_key] = np_z[i]
# Out:
# INFO:tensorflow:Restoring parameters from /tmp/data-kamperh/lazydynamic_latent_ae.ckpt

# %%
# Same-different evaluation
distances = pdist(np_z, metric="cosine")
matches = samediff.generate_matches_array(labels)
ap, prb = samediff.average_precision(
    distances[matches == True], distances[matches == False]
    )

print("Average precision: {:.4f}".format(ap))
print("Precision-recall breakeven: {:.4f}".format(prb))
# Out:
# Average precision: 0.0441
# Precision-recall breakeven: 0.0956

# %%
# Plot reconstruction
plt.figure(figsize=(12, 8))
for i in range(5):
    plt.subplot(5, 2, 2*i + 1)
    if i == 0:
        plt.title("Input")
    plt.imshow(np_x[i][:np_x_lengths[i]].T)
    plt.axis("off")
    plt.subplot(5, 2, 2*i + 2)
    if i == 0:
        plt.title("Reconstruction")
    plt.imshow(np_y[i][:np_x_lengths[i]].T)
    plt.axis("off")

# %%
plotting.plot_raw_embeds(
    embed_dict, ["because", "yknow", "people", "something", "anything", "education", "situation"],
    figsize=(12, 8)
    )
